# %% [markdown]
# <a href="https://colab.research.google.com/github/Imran0897/Language_Translation_Eng_to_French/blob/main/Language_Translation_Eng_to_French.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
import re
import os
import nltk
nltk.download("stopwords")
nltk.download('punkt')
import pickle
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras.preprocessing.text import Tokenizer
from tensorflow.keras.preprocessing.sequence import pad_sequences
from tensorflow.keras.layers import LSTM,Embedding,Input,Dense,SpatialDropout1D,Activation
from tensorflow.keras.models import Model,Sequential
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!

# %%
df = pd.read_csv('/content/drive/MyDrive/Practice/eng_-french.csv')

# %%
df
# Out:
#                                   English words/sentences  \
# 0                                                     Hi.
# 1                                                    Run!
# 2                                                    Run!
# 3                                                    Who?
# 4                                                    Wow!
# ...                                                   ...
# 175616  Top-down economics never works, said Obama. "T...
# 175617  A carbon footprint is the amount of carbon dio...
# 175618  Death is something that we're often discourage...
# 175619  Since there are usually multiple websites on a...
# 175620  If someone who doesn't know your background sa...
#
#                                    French words/sentences
# 0                                                  Salut!
# 1                                                 Cours !
# 2                                                Courez !
# 3                                                   Qui ?
# 4                                              Ça alors !
# ...                                                   ...
# 175616  « L'économie en partant du haut vers le bas, ç...
# 175617  Une empreinte carbone est la somme de pollutio...
# 175618  La mort est une chose qu'on nous décourage sou...
# 175619  Puisqu'il y a de multiples sites web sur chaqu...
# 175620  Si quelqu'un qui ne connaît pas vos antécédent...
#
# [175621 rows x 2 columns]

# %%
df.columns = ['English','French']
df.head()
# Out:
#   English      French
# 0     Hi.      Salut!
# 1    Run!     Cours !
# 2    Run!    Courez !
# 3    Who?       Qui ?
# 4    Wow!  Ça alors !

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 175621 entries, 0 to 175620
# Data columns (total 2 columns):
#  #   Column   Non-Null Count   Dtype
# ---  ------   --------------   -----
#  0   English  175621 non-null  object
#  1   French   175621 non-null  object
# dtypes: object(2)
# memory usage: 2.7+ MB

# %%
# Data preprocessing

# %%
# Clean English column

def clean_english(text):
  text = text.lower()
  text = re.sub('[^a-z!?]'," ",text)
  text = nltk.word_tokenize(text)
  text = " ".join([i.strip() for i in text])
  return text

# %%
data=df[:]

# %%
clean_english(data.iloc[1,0])
# Out:
# 'run !'

# %%
# clean french language

def clean_french(text):
  text = text.lower()
  #remove any characters not a-z and ?!,'
  # characters a-z and (éâàçêêëôîû) chars of frensh lang which contain accent
  text = re.sub('[^a-zéâàçêêëôîû!?]'," ",text)
  return text

# %%
data.iloc[4,1],clean_french(data.iloc[4,1])
# Out:
# ('Ça alors\u202f!', 'ça alors !')

# %%
data.iloc[6,1],clean_french(data.iloc[6,1])
# Out:
# ("À l'aide\u202f!", 'à l aide !')

# %%
data['English'] = data['English'].apply(lambda txt:clean_english(txt))
data['French'] = data['French'].apply(lambda txt:clean_french(txt))

# %%
data['English']
# Out:
# 0                                                        hi
# 1                                                     run !
# 2                                                     run !
# 3                                                     who ?
# 4                                                     wow !
#                                 ...
# 175616    top down economics never works said obama the ...
# 175617    a carbon footprint is the amount of carbon dio...
# 175618    death is something that we re often discourage...
# 175619    since there are usually multiple websites on a...
# 175620    if someone who doesn t know your background sa...
# Name: English, Length: 175621, dtype: object

# %%
data['French']
# Out:
# 0                                                    salut!
# 1                                                   cours !
# 2                                                  courez !
# 3                                                     qui ?
# 4                                                ça alors !
#                                 ...
# 175616      l économie en partant du haut vers le bas  ç...
# 175617    une empreinte carbone est la somme de pollutio...
# 175618    la mort est une chose qu on nous décourage sou...
# 175619    puisqu il y a de multiples sites web sur chaqu...
# 175620    si quelqu un qui ne connaît pas vos antécédent...
# Name: French, Length: 175621, dtype: object

# %%
# add <start> <end> token to decoder sentence (French)

data['French'] = data['French'].apply(lambda txt:f"<start> {txt} <end>")

# %%
data.tail(10)
# Out:
#                                                   English  \
# 175611  five tremors in excess of magnitude on the ric...
# 175612  no matter how much you try to convince people ...
# 175613  a child who is a native speaker usually knows ...
# 175614  there are four main causes of alcohol related ...
# 175615  we need to uphold laws against discrimination ...
# 175616  top down economics never works said obama the ...
# 175617  a carbon footprint is the amount of carbon dio...
# 175618  death is something that we re often discourage...
# 175619  since there are usually multiple websites on a...
# 175620  if someone who doesn t know your background sa...
#
#                                                    French
# 175611  <start> cinq secousses dépassant la magnitude ...
# 175612  <start> peu importe le temps que tu passeras à...
# 175613  <start> un enfant qui est un locuteur natif co...
# 175614  <start> il y a quatre causes principales de dé...
# 175615  <start> nous devons faire respecter les lois c...
# 175616  <start>   l économie en partant du haut vers l...
# 175617  <start> une empreinte carbone est la somme de ...
# 175618  <start> la mort est une chose qu on nous décou...
# 175619  <start> puisqu il y a de multiples sites web s...
# 175620  <start> si quelqu un qui ne connaît pas vos an...

# %%
# tokenization and build vocabalury

english_tokenize=Tokenizer(filters='#$%&()*+,-./:;<=>@[\\]^_`{|}~\t\n')
english_tokenize.fit_on_texts(data["English"])

# %%
num_encoder_tokens=len(english_tokenize.word_index)
num_encoder_tokens
# Out:
# 13905

# %%
encoder=english_tokenize.texts_to_sequences(data["English"])

# %%
encoder[:5]
# Out:
# [[2752], [417, 124], [417, 124], [76, 5], [3489, 124]]

# %%
max_encoder_sequence_len=np.max([len(enc) for enc in encoder])
max_encoder_sequence_len
# Out:
# 47

# %%
french_tokenize=Tokenizer(filters="#$%&()*+,-./:;<=>@[\\]^_`{|}~\t\n")
french_tokenize.fit_on_texts(data["French"])

# %%
num_decoder_tokens=len(french_tokenize.word_index)
num_decoder_tokens
# Out:
# 24129

# %%
decoder=french_tokenize.texts_to_sequences(data["French"])
decoder[:5]
# Out:
# [[2, 15399, 1],
#  [2, 551, 40, 1],
#  [2, 4807, 40, 1],
#  [2, 46, 6, 1],
#  [2, 38, 381, 40, 1]]

# %%
max_decoder_sequence_len=np.max([len(dec) for dec in decoder])
max_decoder_sequence_len
# Out:
# 61

# %%
idx_2_txt_encoder={k:i for i,k in english_tokenize.word_index.items()}
idx_2_txt_encoder
# Out:
# {1: 'i',
#  2: 'you',
#  3: 'to',
#  4: 'the',
#  5: '?',
#  6: 'a',
#  7: 't',
#  8: 'is',
#  9: 'that',
#  10: 'tom',
#  11: 'it',
#  12: 'he',
#  13: 's',
#  14: 'do',
#  15: 'of',
#  16: 'this',
#  17: 'in',
#  18: 'me',
#  19: 'have',
#  20: 'don',
#  21: 'we',
#  22: 'was',
#  23: 'what',
#  24: 'my',
#  25: 'can',
#  26: 'for',
#  27: 'are',
#  28: 'm',
#  29: 'your',
#  30: 'be',
#  31: 're',
#  32: 'she',
#  33: 'want',
#  34: 'not',
#  35: 'know',
#  36: 'like',
#  37: 'on',
#  38: 'with',
#  39: 'they',
#  40: 'his',
#  41: 'all',
#  42: 'did',
#  43: 'at',
#  44: 'how',
#  45: 'go',
#  46: 'think',
#  47: 'there',
#  48: 'll',
#  49: 'him',
#  50: 've',
#  51: 'and',
#  52: 'time',
#  53: 'about',
#  54: 'here',
#  55: 'very',
#  56: 'didn',
#  57: 'get',
#  58: 'were',
#  59: 'no',
#  60: 'as',
#  61: 'one',
#  62: 'her',
#  63: 'will',
#  64: 'had',
#  65: 'if',
#  66: 'why',
#  67: 'just',
#  68: 'up',
#  69: 'out',
#  70: 'going',
#  71: 'has',
#  72: 'd',
#  73: 'would',
#  74: 'so',
#  75: 'need',
#  76: 'who',
#  77: 'good',
#  78: 'mary',
#  79: 'tell',
#  80: 'let',
#  81: 'should',
#  82: 'an',
#  83: 'see',
#  84: 'when',
#  85: 'come',
#  86: 'really',
#  87: 'help',
#  88: 'from',
#  89: 'by',
#  90: 'us',
#  91: 'where',
#  92: 'could',
#  93: 'please',
#  94: 'been',
#  95: 'never',
#  96: 'now',
#  97: 'take',
#  98: 'more',
#  99: 'something',
#  100: 'got',
#  101: 'too',
#  102: 'much',
#  103: 'than',
#  104: 'make',
#  105: 'some',
#  106: 'but',
#  107: 'right',
#  108: 'work',
#  109: 'money',
#  110: 'home',
#  111: 'last',
#  112: 'thought',
#  113: 'any',
#  114: 'say',
#  115: 'anything',
#  116: 'am',
#  117: 'day',
#  118: 'sure',
#  119: 'back',
#  120: 'look',
#  121: 'told',
#  122: 'car',
#  123: 'give',
#  124: '!',
#  125: 'talk',
#  126: 'doesn',
#  127: 'people',
#  128: 'lot',
#  129: 'must',
#  130: 'made',
#  131: 'today',
#  132: 'our',
#  133: 'way',
#  134: 'said',
#  135: 'many',
#  136: 'love',
#  137: 'long',
#  138: 'still',
#  139: 'doing',
#  140: 'won',
#  141: 'feel',
#  142: 'only',
#  143: 'went',
#  144: 'better',
#  145: 'happy',
#  146: 'eat',
#  147: 'always',
#  148: 'isn',
#  149: 'french',
#  150: 'house',
#  151: 'new',
#  152: 'leave',
#  153: 'again',
#  154: 'before',
#  155: 'night',
#  156: 'believe',
#  157: 'book',
#  158: 'room',
#  159: 'does',
#  160: 'them',
#  161: 'off',
#  162: 'school',
#  163: 'job',
#  164: 'little',
#  165: 'well',
#  166: 'everything',
#  167: 'old',
#  168: 'wanted',
#  169: 'father',
#  170: 'tomorrow',
#  171: 'may',
#  172: 'down',
#  173: 'yesterday',
#  174: 'stay',
#  175: 'left',
#  176: 'alone',
#  177: 'three',
#  178: 'happened',
#  179: 'two',
#  180: 'every',
#  181: 'put',
#  182: 'enough',
#  183: 'find',
#  184: 'over',
#  185: 'done',
#  186: 'asked',
#  187: 'stop',
#  188: 'understand',
#  189: 'speak',
#  190: 'these',
#  191: 'man',
#  192: 'nothing',
#  193: 'try',
#  194: 'saw',
#  195: 'ask',
#  196: 'into',
#  197: 'ever',
#  198: 'problem',
#  199: 'or',
#  200: 'next',
#  201: 'keep',
#  202: 'buy',
#  203: 'friends',
#  204: 'dog',
#  205: 'sorry',
#  206: 'hard',
#  207: 'call',
#  208: 'hope',
#  209: 'after',
#  210: 'read',
#  211: 'busy',
#  212: 'friend',
#  213: 'away',
#  214: 'wrong',
#  215: 'everyone',
#  216: 'other',
#  217: 'life',
#  218: 'things',
#  219: 'live',
#  220: 'first',
#  221: 'late',
#  222: 'door',
#  223: 'thing',
#  224: 'idea',
#  225: 'wasn',
#  226: 'mother',
#  227: 'hear',
#  228: 'anyone',
#  229: 'remember',
#  230: 'without',
#  231: 'boston',
#  232: 'looking',
#  233: 'children',
#  234: 'years',
#  235: 'being',
#  236: 'already',
#  237: 'gave',
#  238: 'yet',
#  239: 'came',
#  240: 'couldn',
#  241: 'knew',
#  242: 'took',
#  243: 'used',
#  244: 'their',
#  245: 'name',
#  246: 'morning',
#  247: 'kind',
#  248: 'mind',
#  249: 'tired',
#  250: 'drink',
#  251: 'bad',
#  252: 'seen',
#  253: 'best',
#  254: 'heard',
#  255: 'haven',
#  256: 'teacher',
#  257: 'wait',
#  258: 'lost',
#  259: 'aren',
#  260: 'play',
#  261: 'week',
#  262: 'found',
#  263: 'often',
#  264: 'same',
#  265: 'even',
#  266: 'ready',
#  267: 'water',
#  268: 'care',
#  269: 'soon',
#  270: 'afraid',
#  271: 'use',
#  272: 'answer',
#  273: 'bed',
#  274: 'wish',
#  275: 'yourself',
#  276: 'someone',
#  277: 'else',
#  278: 'big',
#  279: 'few',
#  280: 'happen',
#  281: 'party',
#  282: 'myself',
#  283: 'english',
#  284: 'parents',
#  285: 'while',
#  286: 'train',
#  287: 'cold',
#  288: 'talking',
#  289: 'bought',
#  290: 'open',
#  291: 'year',
#  292: 'show',
#  293: 'glad',
#  294: 'both',
#  295: 'wants',
#  296: 'nice',
#  297: 'around',
#  298: 'getting',
#  299: 'might',
#  300: 'place',
#  301: 'early',
#  302: 'able',
#  303: 'true',
#  304: 'great',
#  305: 'everybody',
#  306: 'because',
#  307: 'knows',
#  308: 'married',
#  309: 'another',
#  310: 'watch',
#  311: 'looks',
#  312: 'those',
#  313: 'turn',
#  314: 'sleep',
#  315: 'such',
#  316: 'tried',
#  317: 'question',
#  318: 'wouldn',
#  319: 'plan',
#  320: 'pay',
#  321: 'hurt',
#  322: 'brother',
#  323: 'beautiful',
#  324: 'write',
#  325: 'almost',
#  326: 'anymore',
#  327: 'food',
#  328: 'walk',
#  329: 'which',
#  330: 'matter',
#  331: 'once',
#  332: 'meeting',
#  333: 'young',
#  334: 'days',
#  335: 'person',
#  336: 'fun',
#  337: 'truth',
#  338: 'coffee',
#  339: 'dinner',
#  340: 'shouldn',
#  341: 'bus',
#  342: 'letter',
#  343: 'coming',
#  344: 'most',
#  345: 'meet',
#  346: 'mine',
#  347: 'sister',
#  348: 'met',
#  349: 'each',
#  350: 'seem',
#  351: 'waiting',
#  352: 'tonight',
#  353: 'family',
#  354: 'change',
#  355: 'books',
#  356: 'nobody',
#  357: 'doctor',
#  358: 'careful',
#  359: 'together',
#  360: 'hate',
#  361: 'since',
#  362: 'trying',
#  363: 'world',
#  364: 'working',
#  365: 'own',
#  366: 'study',
#  367: 'felt',
#  368: 'likes',
#  369: 'forget',
#  370: 'seems',
#  371: 'phone',
#  372: 'longer',
#  373: 'easy',
#  374: 'learn',
#  375: 'girl',
#  376: 'pretty',
#  377: 'word',
#  378: 'important',
#  379: 'far',
#  380: 'station',
#  381: 'died',
#  382: 'hand',
#  383: 'boy',
#  384: 'started',
#  385: 'mean',
#  386: 'wife',
#  387: 'start',
#  388: 'child',
#  389: 'accident',
#  390: 'sick',
#  391: 'gone',
#  392: 'rain',
#  393: 'cat',
#  394: 'finished',
#  395: 'surprised',
#  396: 'drive',
#  397: 'difficult',
#  398: 'quite',
#  399: 'looked',
#  400: 'anybody',
#  401: 'questions',
#  402: 'thank',
#  403: 'lunch',
#  404: 'mistake',
#  405: 'until',
#  406: 'bit',
#  407: 'movie',
#  408: 'yours',
#  409: 'weather',
#  410: 'reading',
#  411: 'story',
#  412: 'office',
#  413: 'ten',
#  414: 'wonder',
#  415: 'makes',
#  416: 'supposed',
#  417: 'run',
#  418: 'swim',
#  419: 'having',
#  420: 'times',
#  421: 'close',
#  422: 'son',
#  423: 'ago',
#  424: 'hours',
#  425: 'small',
#  426: 'playing',
#  427: 'trust',
#  428: 'angry',
#  429: 'stupid',
#  430: 'spend',
#  431: 'tv',
#  432: 'broke',
#  433: 'guess',
#  434: 'says',
#  435: 'minutes',
#  436: 'exactly',
#  437: 'advice',
#  438: 'students',
#  439: 'eyes',
#  440: 'picture',
#  441: 'himself',
#  442: 'music',
#  443: 'hurry',
#  444: 'police',
#  445: 'fire',
#  446: 'usually',
#  447: 'called',
#  448: 'afternoon',
#  449: 'free',
#  450: 'window',
#  451: 'eating',
#  452: 'caught',
#  453: 'lives',
#  454: 'fell',
#  455: 'decided',
#  456: 'turned',
#  457: 'probably',
#  458: 'japan',
#  459: 'interested',
#  460: 'weren',
#  461: 'fast',
#  462: 'table',
#  463: 'interesting',
#  464: 'arrived',
#  465: 'proud',
#  466: 'trouble',
#  467: 'bicycle',
#  468: 'under',
#  469: 'forgot',
#  470: 'ran',
#  471: 'worry',
#  472: 'thinking',
#  473: 'hair',
#  474: 'number',
#  475: 'country',
#  476: 'game',
#  477: 'stand',
#  478: 'chance',
#  479: 'town',
#  480: 'news',
#  481: 'light',
#  482: 'park',
#  483: 'hot',
#  484: 'bring',
#  485: 'listen',
#  486: 'agree',
#  487: 'safe',
#  488: 'promise',
#  489: 'sit',
#  490: 'homework',
#  491: 'japanese',
#  492: 'enjoy',
#  493: 'different',
#  494: 'later',
#  495: 'age',
#  496: 'catch',
#  497: 'advised',
#  498: 'through',
#  499: 'high',
#  500: 'maybe',
#  501: 'possible',
#  502: 'finish',
#  503: 'saying',
#  504: 'against',
#  505: 'living',
#  506: 'end',
#  507: 'appreciate',
#  508: 'reason',
#  509: 'miss',
#  510: 'then',
#  511: 'outside',
#  512: 'lie',
#  513: 'hands',
#  514: 'sing',
#  515: 'win',
#  516: 'summer',
#  517: 'taking',
#  518: 'favorite',
#  519: 'wine',
#  520: 'visit',
#  521: 'quit',
#  522: 'needs',
#  523: 'kept',
#  524: 'five',
#  525: 'shoes',
#  526: 'become',
#  527: 'tree',
#  528: 'dead',
#  529: 'making',
#  530: 'cut',
#  531: 'hungry',
#  532: 'business',
#  533: 'girlfriend',
#  534: 'part',
#  535: 'behind',
#  536: 'born',
#  537: 'month',
#  538: 'box',
#  539: 'moment',
#  540: 'daughter',
#  541: 'ok',
#  542: 'near',
#  543: 'older',
#  544: 'class',
#  545: 'red',
#  546: 'die',
#  547: 'guy',
#  548: 'trip',
#  549: 'rich',
#  550: 'lose',
#  551: 'woman',
#  552: 'tea',
#  553: 'needed',
#  554: 'choice',
#  555: 'paid',
#  556: 'stayed',
#  557: 'works',
#  558: 'face',
#  559: 'somebody',
#  560: 'baby',
#  561: 'city',
#  562: 'company',
#  563: 'eaten',
#  564: 'full',
#  565: 'rest',
#  566: 'breakfast',
#  567: 'dress',
#  568: 'song',
#  569: 'team',
#  570: 'ate',
#  571: 'clothes',
#  572: 'fish',
#  573: 'secret',
#  574: 'serious',
#  575: 'student',
#  576: 'beer',
#  577: 'tennis',
#  578: 'funny',
#  579: 'explain',
#  580: 'clock',
#  581: 'computer',
#  582: 'quickly',
#  583: 'crazy',
#  584: 'hour',
#  585: 'sound',
#  586: 'point',
#  587: 'cost',
#  588: 'expensive',
#  589: 'large',
#  590: 'kids',
#  591: 'invited',
#  592: 'watching',
#  593: 'clean',
#  594: 'break',
#  595: 'monday',
#  596: 'minute',
#  597: 'australia',
#  598: 'hat',
#  599: 'smoking',
#  600: 'asleep',
#  601: 'wearing',
#  602: 'key',
#  603: 'hotel',
#  604: 'scared',
#  605: 'feeling',
#  606: 'real',
#  607: 'death',
#  608: 'sometimes',
#  609: 'comes',
#  610: 'hospital',
#  611: 'lucky',
#  612: 'short',
#  613: 'decision',
#  614: 'between',
#  615: 'spent',
#  616: 'milk',
#  617: 'worried',
#  618: 'began',
#  619: 'language',
#  620: 'goes',
#  621: 'words',
#  622: 'lived',
#  623: 'problems',
#  624: 'whole',
#  625: 'became',
#  626: 'others',
#  627: 'telling',
#  628: 'studying',
#  629: 'handle',
#  630: 'river',
#  631: 'changed',
#  632: 'touch',
#  633: 'expect',
#  634: 'boss',
#  635: 'street',
#  636: 'hit',
#  637: 'dark',
#  638: 'thirty',
#  639: 'cake',
#  640: 'snow',
#  641: 'war',
#  642: 'speaking',
#  643: 'front',
#  644: 'deal',
#  645: 'cup',
#  646: 'drunk',
#  647: 'killed',
#  648: 'six',
#  649: 'present',
#  650: 'store',
#  651: 'situation',
#  652: 'liked',
#  653: 'wrote',
#  654: 'closed',
#  655: 'takes',
#  656: 'birthday',
#  657: 'rather',
#  658: 'allowed',
#  659: 'hold',
#  660: 'finally',
#  661: 'mistakes',
#  662: 'paper',
#  663: 'report',
#  664: 'stopped',
#  665: 'restaurant',
#  666: 'thanks',
#  667: 'sat',
#  668: 'talked',
#  669: 'quiet',
#  670: 'strong',
#  671: 'missed',
#  672: 'strange',
#  673: 'known',
#  674: 'helped',
#  675: 'check',
#  676: 'happening',
#  677: 'kill',
#  678: 'gets',
#  679: 'necessary',
#  680: 'actually',
#  681: 'dogs',
#  682: 'list',
#  683: 'second',
#  684: 'building',
#  685: 'worked',
#  686: 'head',
#  687: 'forward',
#  688: 'along',
#  689: 'order',
#  690: 'half',
#  691: 'whether',
#  692: 'dream',
#  693: 'perfect',
#  694: 'coat',
#  695: 'sense',
#  696: 'dangerous',
#  697: 'heart',
#  698: 'weekend',
#  699: 'case',
#  700: 'figured',
#  701: 'tall',
#  702: 'prefer',
#  703: 'expected',
#  704: 'swimming',
#  705: 'speaks',
#  706: 'move',
#  707: 'brought',
#  708: 'health',
#  709: 'evening',
#  710: 'plane',
#  711: 'its',
#  712: 'beach',
#  713: 'men',
#  714: 'upset',
#  715: 'running',
#  716: 'whatever',
#  717: 'dictionary',
#  718: 'follow',
#  719: 'air',
#  720: 'happens',
#  721: 'leaving',
#  722: 'christmas',
#  723: 'completely',
#  724: 'least',
#  725: 'seat',
#  726: 'worth',
#  727: 'shut',
#  728: 'broken',
#  729: 'seeing',
#  730: 'future',
#  731: 'loves',
#  732: 'dance',
#  733: 'disappointed',
#  734: 'walked',
#  735: 'drinking',
#  736: 'dollars',
#  737: 'pain',
#  738: 'sent',
#  739: 'written',
#  740: 'famous',
#  741: 'offer',
#  742: 'rules',
#  743: 'smoke',
#  744: 'luck',
#  745: 'choose',
#  746: 'flowers',
#  747: 'weight',
#  748: 'either',
#  749: 'crying',
#  750: 'wear',
#  751: 'information',
#  752: 'somewhere',
#  753: 'cook',
#  754: 'piano',
#  755: 'camera',
#  756: 'glass',
#  757: 'noise',
#  758: 'learned',
#  759: 'hasn',
#  760: 'white',
#  761: 'writing',
#  762: 'garden',
#  763: 'library',
#  764: 'fine',
#  765: 'apologize',
#  766: 'taken',
#  767: 'opinion',
#  768: 'o',
#  769: 'mad',
#  770: 'accept',
#  771: 'waste',
#  772: 'nervous',
#  773: 'danger',
#  774: 'address',
#  775: 'several',
#  776: 'kiss',
#  777: 'road',
#  778: 'save',
#  779: 'husband',
#  780: 'attention',
#  781: 'during',
#  782: 'girls',
#  783: 'floor',
#  784: 'umbrella',
#  785: 'alive',
#  786: 'excuse',
#  787: 'listening',
#  788: 'sunday',
#  789: 'fix',
#  790: 'guys',
#  791: 'poor',
#  792: 'set',
#  793: 'lawyer',
#  794: 'less',
#  795: 'solve',
#  796: 'join',
#  797: 'loved',
#  798: 'women',
#  799: 'sleeping',
#  800: 'owe',
#  801: 'clear',
#  802: 'bag',
#  803: 'uncle',
#  804: 'showed',
#  805: 'teach',
#  806: 'shirt',
#  807: 'date',
#  808: 'opened',
#  809: 'thinks',
#  810: 'smart',
#  811: 'grow',
#  812: 'vacation',
#  813: 'suppose',
#  814: 'tie',
#  815: 'blame',
#  816: 'desk',
#  817: 'success',
#  818: 'means',
#  819: 'ticket',
#  820: 'medicine',
#  821: 'wake',
#  822: 'pass',
#  823: 'shopping',
#  824: 'black',
#  825: 'keys',
#  826: 'sad',
#  827: 'prepared',
#  828: 'radio',
#  829: 'lying',
#  830: 'tokyo',
#  831: 'horse',
#  832: 'college',
#  833: 'message',
#  834: 'side',
#  835: 'piece',
#  836: 'whose',
#  837: 'abroad',
#  838: 'telephone',
#  839: 'concert',
#  840: 'spoke',
#  841: 'joke',
#  842: 'sounds',
#  843: 'bank',
#  844: 'discuss',
#  845: 'ship',
#  846: 'asking',
#  847: 'arrive',
#  848: 'guitar',
#  849: 'willing',
#  850: 'promised',
#  851: 'fight',
#  852: 'dressed',
#  853: 'plans',
#  854: 'borrow',
#  855: 'glasses',
#  856: 'boyfriend',
#  857: 'shot',
#  858: 'waited',
#  859: 'cats',
#  860: 'driving',
#  861: 'send',
#  862: 'apple',
#  863: 'difference',
#  864: 'immediately',
#  865: 'across',
#  866: 'price',
#  867: 'afford',
#  868: 'carefully',
#  869: 'speech',
#  870: 'pictures',
#  871: 'four',
#  872: 'given',
#  873: 'cry',
#  874: 'certain',
#  875: 'kid',
#  876: 'lake',
#  877: 'fat',
#  878: 'sign',
#  879: 'boys',
#  880: 'movies',
#  881: 'shower',
#  882: 'harder',
#  883: 'none',
#  884: 'inside',
#  885: 'gun',
#  886: 'involved',
#  887: 'travel',
#  888: 'lend',
#  889: 'color',
#  890: 'regret',
#  891: 'agreed',
#  892: 'fired',
#  893: 'patient',
#  894: 'ride',
#  895: 'satisfied',
#  896: 'fault',
#  897: 'impossible',
#  898: 'test',
#  899: 'succeed',
#  900: 'empty',
#  901: 'traffic',
#  902: 'begin',
#  903: 'kissed',
#  904: 'arm',
#  905: 'worse',
#  906: 'couple',
#  907: 'painting',
#  908: 'ahead',
#  909: 'honest',
#  910: 'correct',
#  911: 'staying',
#  912: 'earlier',
#  913: 'bill',
#  914: 'novel',
#  915: 'earth',
#  916: 'cute',
#  917: 'enjoyed',
#  918: 'twice',
#  919: 'meat',
#  920: 'raining',
#  921: 'ice',
#  922: 'blue',
#  923: 'easily',
#  924: 'slept',
#  925: 'played',
#  926: 'storm',
#  927: 'anywhere',
#  928: 'pen',
#  929: 'line',
#  930: 'winter',
#  931: 'walking',
#  932: 'chair',
#  933: 'hardly',
#  934: 'held',
#  935: 'count',
#  936: 'passed',
#  937: 'lock',
#  938: 'america',
#  939: 'sitting',
#  940: 'foreign',
#  941: 'decide',
#  942: 'laugh',
#  943: 'act',
#  944: 'american',
#  945: 'likely',
#  946: 'figure',
#  947: 'television',
#  948: 'machine',
#  949: 'smell',
#  950: 'singing',
#  951: 'animals',
#  952: 'experience',
#  953: 'weeks',
#  954: 'lied',
#  955: 'wonderful',
#  956: 'terrible',
#  957: 'fishing',
#  958: 'airport',
#  959: 'warm',
#  960: 'control',
#  961: 'heavy',
#  962: 'sooner',
#  963: 'consider',
#  964: 'fall',
#  965: 'mom',
#  966: 'prison',
#  967: 'followed',
#  968: 'surprise',
#  969: 'ideas',
#  970: 'past',
#  971: 'shop',
#  972: 'newspaper',
#  973: 'also',
#  974: 'laughed',
#  975: 'refused',
#  976: 'boat',
#  977: 'injured',
#  978: 'younger',
#  979: 'driver',
#  980: 'gotten',
#  981: 'carry',
#  982: 'sell',
#  983: 'drank',
#  984: 'sun',
#  985: 'mountain',
#  986: 'cooking',
#  987: 'apples',
#  988: 'law',
#  989: 'gift',
#  990: 'charge',
#  991: 'leaves',
#  992: 'beginning',
#  993: 'herself',
#  994: 'failed',
#  995: 'weird',
#  996: 'pick',
#  997: 'bother',
#  998: 'sugar',
#  999: 'painted',
#  1000: 'duty',
#  ...}

# %%
idx_2_txt_decoder={k:i for i,k in french_tokenize.word_index.items()}
idx_2_txt_decoder
# Out:
# {1: 'end',
#  2: 'start',
#  3: 'je',
#  4: 'de',
#  5: 'pas',
#  6: '?',
#  7: 'est',
#  8: 'vous',
#  9: 'que',
#  10: 'il',
#  11: 'à',
#  12: 'ne',
#  13: 'le',
#  14: 'la',
#  15: 'tu',
#  16: 'ce',
#  17: 'a',
#  18: 'j',
#  19: 'n',
#  20: 'tom',
#  21: 'l',
#  22: 'un',
#  23: 'ai',
#  24: 'nous',
#  25: 'en',
#  26: 'd',
#  27: 'une',
#  28: 's',
#  29: 'les',
#  30: 'me',
#  31: 'suis',
#  32: 'c',
#  33: 'pour',
#  34: 'elle',
#  35: 'qu',
#  36: 'faire',
#  37: 're',
#  38: 'ça',
#  39: 'm',
#  40: '!',
#  41: 'dans',
#  42: 'y',
#  43: 'plus',
#  44: 'des',
#  45: 'te',
#  46: 'qui',
#  47: 'moi',
#  48: 'tout',
#  49: 'veux',
#  50: 't',
#  51: 'être',
#  52: 'fait',
#  53: 'était',
#  54: 'avec',
#  55: 'êtes',
#  56: 'mon',
#  57: 'du',
#  58: 'au',
#  59: 'si',
#  60: 'se',
#  61: 'as',
#  62: 'et',
#  63: 'avez',
#  64: 'sont',
#  65: 'cette',
#  66: 'ils',
#  67: 'es',
#  68: 'son',
#  69: 'tr',
#  70: 'peux',
#  71: 'cela',
#  72: 'votre',
#  73: 'temps',
#  74: 'pourquoi',
#  75: 'été',
#  76: 'dit',
#  77: 'sur',
#  78: 'lui',
#  79: 'ici',
#  80: 'ma',
#  81: 'pense',
#  82: 'sais',
#  83: 'chose',
#  84: 'jamais',
#  85: 'toi',
#  86: 'on',
#  87: 'o',
#  88: 'comment',
#  89: 'vraiment',
#  90: 'bien',
#  91: 'avons',
#  92: 'ton',
#  93: 'dire',
#  94: 'ont',
#  95: 'quelque',
#  96: 'sa',
#  97: 'par',
#  98: 'tous',
#  99: 'aller',
#  100: 'avoir',
#  101: 'beaucoup',
#  102: 'besoin',
#  103: 'elles',
#  104: 'aime',
#  105: 'là',
#  106: 'personne',
#  107: 'peut',
#  108: 'mes',
#  109: 'sommes',
#  110: 'étais',
#  111: 'rien',
#  112: 'parler',
#  113: 'peu',
#  114: 'train',
#  115: 'maison',
#  116: 'mary',
#  117: 'toujours',
#  118: 'trop',
#  119: 'comme',
#  120: 'même',
#  121: 'deux',
#  122: 'va',
#  123: 'quoi',
#  124: 'voir',
#  125: 'argent',
#  126: 'quand',
#  127: 'encore',
#  128: 'monde',
#  129: 'avait',
#  130: 'mais',
#  131: 'dois',
#  132: 'bon',
#  133: 'vais',
#  134: 'soit',
#  135: 'voiture',
#  136: 'aimerais',
#  137: 'faut',
#  138: 'autre',
#  139: 'ses',
#  140: 'ta',
#  141: 'fois',
#  142: 'maintenant',
#  143: 'combien',
#  144: 'travail',
#  145: 'ceci',
#  146: 'aujourd',
#  147: 'hui',
#  148: 'aussi',
#  149: 'avais',
#  150: 'vu',
#  151: 'air',
#  152: 'hier',
#  153: 'probl',
#  154: 'quelle',
#  155: 'p',
#  156: 'pouvez',
#  157: 'juste',
#  158: 'quel',
#  159: 'fais',
#  160: 'aider',
#  161: 'ces',
#  162: 'chez',
#  163: 'français',
#  164: 'eu',
#  165: 'apr',
#  166: 'toutes',
#  167: 'pensais',
#  168: 'livre',
#  169: 'déjà',
#  170: 'arrive',
#  171: 'prendre',
#  172: 'assez',
#  173: 'quelqu',
#  174: 'bonne',
#  175: 'mieux',
#  176: 'notre',
#  177: 'demain',
#  178: 'voulez',
#  179: 'porte',
#  180: 'sans',
#  181: 'trois',
#  182: 'devrais',
#  183: 'seul',
#  184: 'avant',
#  185: 'puis',
#  186: 'école',
#  187: 'heure',
#  188: 'dû',
#  189: 'manger',
#  190: 'tes',
#  191: 'enfants',
#  192: 'vie',
#  193: 'plaît',
#  194: 'savoir',
#  195: 'gens',
#  196: 'mal',
#  197: 'toute',
#  198: 'heures',
#  199: 'aux',
#  200: 'fut',
#  201: 'soir',
#  202: 'homme',
#  203: 'marie',
#  204: 'cet',
#  205: 'nuit',
#  206: 'vos',
#  207: 'moment',
#  208: 'chien',
#  209: 'aide',
#  210: 'simplement',
#  211: 'grand',
#  212: 'jour',
#  213: 'ou',
#  214: 'derni',
#  215: 'quelques',
#  216: 'partir',
#  217: 'aurais',
#  218: 'ans',
#  219: 'voulais',
#  220: 'pris',
#  221: 'idée',
#  222: 'choses',
#  223: 'dis',
#  224: 'sens',
#  225: 'passé',
#  226: 'veut',
#  227: 'venir',
#  228: 'heureux',
#  229: 'esp',
#  230: 'petit',
#  231: 'jours',
#  232: 'boston',
#  233: 'nouveau',
#  234: 'sait',
#  235: 'sûr',
#  236: 'tôt',
#  237: 'depuis',
#  238: 'ur',
#  239: 'rent',
#  240: 'parle',
#  241: 'faites',
#  242: 'rester',
#  243: 'peur',
#  244: 'amis',
#  245: 'croire',
#  246: 'semaine',
#  247: 'difficile',
#  248: 'non',
#  249: 'rendre',
#  250: 'seule',
#  251: 'demandé',
#  252: 'eau',
#  253: 'pu',
#  254: 'fille',
#  255: 'soyez',
#  256: 'raison',
#  257: 'part',
#  258: 'pendant',
#  259: 'savais',
#  260: 'sois',
#  261: 'ami',
#  262: 'pourrais',
#  263: 'chambre',
#  264: 'souvent',
#  265: 'entendu',
#  266: 'jusqu',
#  267: 'pi',
#  268: 'pouvons',
#  269: 'nom',
#  270: 'leur',
#  271: 'parents',
#  272: 'femme',
#  273: 'prie',
#  274: 'longtemps',
#  275: 'fr',
#  276: 'question',
#  277: 'matin',
#  278: 'acheter',
#  279: 'demande',
#  280: 'laisse',
#  281: 'crois',
#  282: 'arrivé',
#  283: 'sera',
#  284: 'anglais',
#  285: 'semble',
#  286: 'tard',
#  287: 'lire',
#  288: 'aucun',
#  289: 'trouver',
#  290: 'étaient',
#  291: 'acheté',
#  292: 'déjeuner',
#  293: 'entre',
#  294: 'trouvé',
#  295: 'fort',
#  296: 'moins',
#  297: 'fête',
#  298: 'aucune',
#  299: 'passe',
#  300: 'res',
#  301: 'devons',
#  302: 'penses',
#  303: 'perdu',
#  304: 'jouer',
#  305: 'lorsque',
#  306: 'pourrait',
#  307: 'retard',
#  308: 'dont',
#  309: 'ville',
#  310: 'désolé',
#  311: 'étiez',
#  312: 'vrai',
#  313: 'presque',
#  314: 'viens',
#  315: 'connais',
#  316: 'lit',
#  317: 'nouvelle',
#  318: 'dites',
#  319: 'sujet',
#  320: 'sortir',
#  321: 'enfant',
#  322: 'travailler',
#  323: 'doit',
#  324: 'téléphone',
#  325: 'accord',
#  326: 'autres',
#  327: 'mort',
#  328: 'devriez',
#  329: 'vérité',
#  330: 'pensez',
#  331: 'attendre',
#  332: 'café',
#  333: 'journée',
#  334: 'allé',
#  335: 'voudrais',
#  336: 'grande',
#  337: 'savez',
#  338: 'allez',
#  339: 'vas',
#  340: 'point',
#  341: 'main',
#  342: 'allons',
#  343: 'chaque',
#  344: 'lettre',
#  345: 'trouve',
#  346: 'davantage',
#  347: 'pensé',
#  348: 'reste',
#  349: 'jeune',
#  350: 'famille',
#  351: 'passer',
#  352: 'entendre',
#  353: 'adore',
#  354: 'devez',
#  355: 'bureau',
#  356: 'veuillez',
#  357: 'merci',
#  358: 'bus',
#  359: 'dix',
#  360: 'histoire',
#  361: 'livres',
#  362: 'petite',
#  363: 'donné',
#  364: 'voulait',
#  365: 'tellement',
#  366: 'laissez',
#  367: 'chance',
#  368: 'ignore',
#  369: 'venu',
#  370: 'essayer',
#  371: 'occupé',
#  372: 'partie',
#  373: 'fini',
#  374: 'envie',
#  375: 'photo',
#  376: 'pouvoir',
#  377: 'année',
#  378: 'nager',
#  379: 'ci',
#  380: 'arrêter',
#  381: 'alors',
#  382: 'celui',
#  383: 'vivre',
#  384: 'comprends',
#  385: 'heureuse',
#  386: 'devrions',
#  387: 'tête',
#  388: 'mis',
#  389: 'mangé',
#  390: 'prends',
#  391: 'donner',
#  392: 'devrait',
#  393: 'mani',
#  394: 'serait',
#  395: 'mauvais',
#  396: 'vite',
#  397: 'erreur',
#  398: 'sous',
#  399: 'seulement',
#  400: 'accident',
#  401: 'apprendre',
#  402: 'réunion',
#  403: 'ensemble',
#  404: 'vois',
#  405: 'fils',
#  406: 'vieux',
#  407: 'prêt',
#  408: 'col',
#  409: 'personnes',
#  410: 'malade',
#  411: 'coup',
#  412: 'écrire',
#  413: 'ferais',
#  414: 'midi',
#  415: 'comprendre',
#  416: 'serais',
#  417: 'nos',
#  418: 'demander',
#  419: 'garçon',
#  420: 'yeux',
#  421: 'serai',
#  422: 'conduire',
#  423: 'nourriture',
#  424: 'âge',
#  425: 'facile',
#  426: 'dur',
#  427: 'questions',
#  428: 'fatigué',
#  429: 'froid',
#  430: 'meilleur',
#  431: 'mois',
#  432: 'déteste',
#  433: 'vue',
#  434: 'écrit',
#  435: 'amie',
#  436: 'pr',
#  437: 'endroit',
#  438: 'apprécie',
#  439: 'bas',
#  440: 'pourriez',
#  441: 'attention',
#  442: 'donne',
#  443: 'importe',
#  444: 'réponse',
#  445: 'autant',
#  446: 'mettre',
#  447: 'regarder',
#  448: 'boire',
#  449: 'oublié',
#  450: 'mot',
#  451: 'film',
#  452: 'chat',
#  453: 'premier',
#  454: 'laissé',
#  455: 'belle',
#  456: 'bientôt',
#  457: 'compte',
#  458: 'feu',
#  459: 'sûre',
#  460: 'confiance',
#  461: 'travaille',
#  462: 'essayé',
#  463: 'ainsi',
#  464: 'place',
#  465: 'minutes',
#  466: 'exactement',
#  467: 'dernier',
#  468: 'pays',
#  469: 'chemin',
#  470: 'parlé',
#  471: 'contre',
#  472: 'police',
#  473: 'regarde',
#  474: 'côté',
#  475: 'laisser',
#  476: 'gare',
#  477: 'dormir',
#  478: 'prix',
#  479: 'possible',
#  480: 'vient',
#  481: 'étudier',
#  482: 'vélo',
#  483: 'tant',
#  484: 'montre',
#  485: 'médecin',
#  486: 'musique',
#  487: 'pouvais',
#  488: 'table',
#  489: 'loin',
#  490: 'suppose',
#  491: 'aurait',
#  492: 'probablement',
#  493: 'quiconque',
#  494: 'dîner',
#  495: 'plan',
#  496: 'premi',
#  497: 'verre',
#  498: 'japon',
#  499: 'genre',
#  500: 'boulot',
#  501: 'plait',
#  502: 'aimes',
#  503: 'prochaine',
#  504: 'dessus',
#  505: 'lieu',
#  506: 'désolée',
#  507: 'professeur',
#  508: 'plutôt',
#  509: 'beau',
#  510: 'cheveux',
#  511: 'arriver',
#  512: 'puisse',
#  513: 'propos',
#  514: 'parti',
#  515: 'leurs',
#  516: 'vit',
#  517: 'dehors',
#  518: 'voyage',
#  519: 'appris',
#  520: 'fenêtre',
#  521: 'affaire',
#  522: 'gros',
#  523: 'auparavant',
#  524: 'penser',
#  525: 'joue',
#  526: 'chanter',
#  527: 'faim',
#  528: 'peuvent',
#  529: 'choix',
#  530: 'décidé',
#  531: 'cinq',
#  532: 'vin',
#  533: 'habitude',
#  534: 'attends',
#  535: 'payer',
#  536: 'important',
#  537: 'étions',
#  538: 'appeler',
#  539: 'arrête',
#  540: 'rencontrer',
#  541: 'ait',
#  542: 'intention',
#  543: 'emploi',
#  544: 'utiliser',
#  545: 'devoirs',
#  546: 'chaud',
#  547: 'prochain',
#  548: 'pouvait',
#  549: 'immédiatement',
#  550: 'vont',
#  551: 'cours',
#  552: 'nouvelles',
#  553: 'agit',
#  554: 'préf',
#  555: 'visite',
#  556: 'perdre',
#  557: 'r',
#  558: 'surpris',
#  559: 'répondre',
#  560: 'lu',
#  561: 'discuter',
#  562: 'terre',
#  563: 'rencontré',
#  564: 'marcher',
#  565: 'fumer',
#  566: 'compl',
#  567: 'parce',
#  568: 'occupée',
#  569: 'prenez',
#  570: 'sécurité',
#  571: 'content',
#  572: 'eux',
#  573: 'peine',
#  574: 'commencé',
#  575: 'bi',
#  576: 'savait',
#  577: 'revoir',
#  578: 'chaussures',
#  579: 'tement',
#  580: 'mains',
#  581: 'celle',
#  582: 'produit',
#  583: 'mange',
#  584: 'terminé',
#  585: 'lundi',
#  586: 'lumi',
#  587: 'santé',
#  588: 'bois',
#  589: 'avion',
#  590: 've',
#  591: 'appelle',
#  592: 'chercher',
#  593: 'riche',
#  594: 'langue',
#  595: 'nombreux',
#  596: 'classe',
#  597: 'rappelle',
#  598: 'équipe',
#  599: 'thé',
#  600: 'faisons',
#  601: 'nécessaire',
#  602: 'vers',
#  603: 'voulons',
#  604: 'tomber',
#  605: 'rentrer',
#  606: 'ferai',
#  607: 'propre',
#  608: 'blessé',
#  609: 'chanson',
#  610: 'secret',
#  611: 'décision',
#  612: 'commence',
#  613: 'laquelle',
#  614: 'trente',
#  615: 'devenir',
#  616: 'derri',
#  617: 'ordinateur',
#  618: 'entrer',
#  619: 'boîte',
#  620: 'rapidement',
#  621: 'tennis',
#  622: 'lorsqu',
#  623: 'aimé',
#  624: 'fit',
#  625: 'numéro',
#  626: 'cause',
#  627: 'télévision',
#  628: 'étudiants',
#  629: 'souviens',
#  630: 'journal',
#  631: 'façon',
#  632: 'essaie',
#  633: 'appelé',
#  634: 'ayez',
#  635: 'vacances',
#  636: 'rement',
#  637: 'reçu',
#  638: 'bruit',
#  639: 'bébé',
#  640: 'arbre',
#  641: 'aimez',
#  642: 'vouloir',
#  643: 'mauvaise',
#  644: 'changer',
#  645: 'dispose',
#  646: 'magasin',
#  647: 'hôtel',
#  648: 'vis',
#  649: 'affaires',
#  650: 'donc',
#  651: 'sorte',
#  652: 'instant',
#  653: 'route',
#  654: 'montrer',
#  655: 'australie',
#  656: 'hôpital',
#  657: 'quatre',
#  658: 'devant',
#  659: 'plein',
#  660: 'assis',
#  661: 'poser',
#  662: 'dollars',
#  663: 'tort',
#  664: 'guerre',
#  665: 'ceux',
#  666: 'chapeau',
#  667: 'étranger',
#  668: 'situation',
#  669: 'prête',
#  670: 'robe',
#  671: 'stupide',
#  672: 'neige',
#  673: 'font',
#  674: 'fin',
#  675: 'fier',
#  676: 'rouge',
#  677: 'cadeau',
#  678: 'intéressant',
#  679: 'soin',
#  680: 'garder',
#  681: 'fasse',
#  682: 'lait',
#  683: 'clé',
#  684: 'faisait',
#  685: 'anniversaire',
#  686: 'poste',
#  687: 'rue',
#  688: 'vêtements',
#  689: 'commencer',
#  690: 'sac',
#  691: 'soleil',
#  692: 'veulent',
#  693: 'restaurant',
#  694: 'voudriez',
#  695: 'long',
#  696: 'six',
#  697: 'années',
#  698: 'arrêté',
#  699: 'amies',
#  700: 'parc',
#  701: 'vieille',
#  702: 'gagner',
#  703: 'droit',
#  704: 'parfois',
#  705: 'nombreuses',
#  706: 'donnez',
#  707: 'cuisine',
#  708: 'pleurer',
#  709: 'retour',
#  710: 'capable',
#  711: 'désormais',
#  712: 'conseil',
#  713: 'bras',
#  714: 'marché',
#  715: 'voulu',
#  716: 'certain',
#  717: 'meilleure',
#  718: 'libre',
#  719: 'plaisir',
#  720: 'prend',
#  721: 'examen',
#  722: 'garde',
#  723: 'japonais',
#  724: 'type',
#  725: 'minute',
#  726: 'noël',
#  727: 'parlez',
#  728: 'gâteau',
#  729: 'lequel',
#  730: 'dimanche',
#  731: 'venez',
#  732: 'pied',
#  733: 'carte',
#  734: 'filles',
#  735: 'mots',
#  736: 'mourir',
#  737: 'liste',
#  738: 'rire',
#  739: 'suffisamment',
#  740: 'cas',
#  741: 'rapport',
#  742: 'pluie',
#  743: 'ouvrir',
#  744: 'aies',
#  745: 'plage',
#  746: 'voici',
#  747: 'rendu',
#  748: 'résoudre',
#  749: 'oublie',
#  750: 'télé',
#  751: 'hommes',
#  752: 'manteau',
#  753: 'moindre',
#  754: 'demanda',
#  755: 'plusieurs',
#  756: 'changé',
#  757: 'vaut',
#  758: 'porter',
#  759: 'rivi',
#  760: 'finalement',
#  761: 'dictionnaire',
#  762: 'week',
#  763: 'telle',
#  764: 'devoir',
#  765: 'tasse',
#  766: 'furent',
#  767: 'chiens',
#  768: 'rendez',
#  769: 'excuses',
#  770: 'fleurs',
#  771: 'écouter',
#  772: 'compris',
#  773: 'amour',
#  774: 'connaît',
#  775: 'étrange',
#  776: 'réparer',
#  777: 'rêve',
#  778: 'seriez',
#  779: 'finir',
#  780: 'mesure',
#  781: 'surprise',
#  782: 'succ',
#  783: 'feriez',
#  784: 'jardin',
#  785: 'mets',
#  786: 'rend',
#  787: 'aviez',
#  788: 'biblioth',
#  789: 'fou',
#  790: 'payé',
#  791: 'piano',
#  792: 'poids',
#  793: 'suite',
#  794: 'erreurs',
#  795: 'expliquer',
#  796: 'bateau',
#  797: 'dormi',
#  798: 'gles',
#  799: 'appareil',
#  800: 'grosse',
#  801: 'amoureux',
#  802: 'volé',
#  803: 'souhaite',
#  804: 'poisson',
#  805: 'pleuvoir',
#  806: 'avions',
#  807: 'dangereux',
#  808: 'plupart',
#  809: 'restez',
#  810: 'allée',
#  811: 'fi',
#  812: 'serez',
#  813: 'venue',
#  814: 'noir',
#  815: 'prison',
#  816: 'allait',
#  817: 'gentil',
#  818: 'arrêtez',
#  819: 'mit',
#  820: 'autour',
#  821: 'femmes',
#  822: 'attendais',
#  823: 'projet',
#  824: 'quels',
#  825: 'hors',
#  826: 'regardé',
#  827: 'resté',
#  828: 'regardez',
#  829: 'faute',
#  830: 'repas',
#  831: 'parapluie',
#  832: 'auriez',
#  833: 'danser',
#  834: 'bu',
#  835: 'lunettes',
#  836: 'cher',
#  837: 'adresse',
#  838: 'quitter',
#  839: 'entends',
#  840: 'jeu',
#  841: 'marche',
#  842: 'h',
#  843: 'sommeil',
#  844: 'fatiguée',
#  845: 'pommes',
#  846: 'salle',
#  847: 'court',
#  848: 'sérieux',
#  849: 'face',
#  850: 'danger',
#  851: 'aie',
#  852: 'oncle',
#  853: 'pire',
#  854: 'devenu',
#  855: 'fera',
#  856: 'expérience',
#  857: 'tenir',
#  858: 'tour',
#  859: 'asseoir',
#  860: 'coucher',
#  861: 'travers',
#  862: 'fonctionne',
#  863: 'ouvert',
#  864: 'parviens',
#  865: 'manque',
#  866: 'certains',
#  867: 'dirait',
#  868: 'proposition',
#  869: 'durant',
#  870: 'tombé',
#  871: 'avocat',
#  872: 'radio',
#  873: 'rappeler',
#  874: 'car',
#  875: 'avis',
#  876: 'seconde',
#  877: 'né',
#  878: 'cent',
#  879: 'aidé',
#  880: 'bizarre',
#  881: 'essayez',
#  882: 'réussi',
#  883: 'patron',
#  884: 'coûte',
#  885: 'fermer',
#  886: 'esprit',
#  887: 'avaient',
#  888: 'voyager',
#  889: 'photos',
#  890: 'opinion',
#  891: 'cassé',
#  892: 'souci',
#  893: 'cherche',
#  894: 'prit',
#  895: 'réjouis',
#  896: 'tableau',
#  897: 'inconvénient',
#  898: 'rends',
#  899: 'ach',
#  900: 'tokyo',
#  901: 'seras',
#  902: 'impression',
#  903: 'gagné',
#  904: 'courir',
#  905: 'simple',
#  906: 'haut',
#  907: 'lever',
#  908: 'courant',
#  909: 'mari',
#  910: 'occasion',
#  911: 'mariage',
#  912: 'neuf',
#  913: 'prudent',
#  914: 'doute',
#  915: 'garçons',
#  916: 'bonnes',
#  917: 'donna',
#  918: 'taxi',
#  919: 'ni',
#  920: 'entreprise',
#  921: 'impossible',
#  922: 'sorti',
#  923: 'attendu',
#  924: 'conseils',
#  925: 'étudiant',
#  926: 'papier',
#  927: 'concert',
#  928: 'triste',
#  929: 'allés',
#  930: 'étudie',
#  931: 'habite',
#  932: 'cheval',
#  933: 'empêcher',
#  934: 'fus',
#  935: 'chats',
#  936: 'bons',
#  937: 'invité',
#  938: 'enseignant',
#  939: 'message',
#  940: 'chemise',
#  941: 'présenter',
#  942: 'lac',
#  943: 'ignorais',
#  944: 'bâtiment',
#  945: 'différence',
#  946: 'ferme',
#  947: 'savons',
#  948: 'également',
#  949: 'pieds',
#  950: 'voix',
#  951: 'ch',
#  952: 'intérieur',
#  953: 'proche',
#  954: 'amusant',
#  955: 'animaux',
#  956: 'connaître',
#  957: 'vingt',
#  958: 'signifie',
#  959: 'él',
#  960: 'moyen',
#  961: 'occuper',
#  962: 'attraper',
#  963: 'banque',
#  964: 'ciel',
#  965: 'menti',
#  966: 'présent',
#  967: 'certaines',
#  968: 'clés',
#  969: 'supporter',
#  970: 'emprunter',
#  971: 'tempête',
#  972: 'suivre',
#  973: 'couleur',
#  974: 'promets',
#  975: 'idiot',
#  976: 'senti',
#  977: 'ge',
#  978: 'douleur',
#  979: 'contente',
#  980: 'réfléchir',
#  981: 'préféré',
#  982: 'jeunes',
#  983: 'guitare',
#  984: 'aille',
#  985: 'viande',
#  986: 'rhume',
#  987: 'environ',
#  988: 'promis',
#  989: 'irai',
#  990: 'viendra',
#  991: 'certaine',
#  992: 'travaillé',
#  993: 'dedans',
#  994: 'oui',
#  995: 'drôle',
#  996: 'écoute',
#  997: 'arme',
#  998: 'sentir',
#  999: 'chaise',
#  1000: 'roman',
#  ...}

# %%
idx_2_txt_decoder[0]="<pad>"
idx_2_txt_encoder[0]="<pad>"

# %%
idx_2_txt_encoder[0]
# Out:
# '<pad>'

# %%
# Pad Sequence

# %%
encoder_seq=pad_sequences(encoder,maxlen=max_encoder_sequence_len,padding="post")
encoder_seq.shape
# Out:
# (175621, 47)

# %%
encoder_seq
# Out:
# array([[2752,    0,    0, ...,    0,    0,    0],
#        [ 417,  124,    0, ...,    0,    0,    0],
#        [ 417,  124,    0, ...,    0,    0,    0],
#        ...,
#        [ 607,    8,   99, ...,    0,    0,    0],
#        [ 361,   47,   27, ...,    0,    0,    0],
#        [  65,  276,   76, ...,    6, 1100, 1448]], dtype=int32)

# %%
decoder_inp=pad_sequences([arr[:-1] for arr in decoder],maxlen=max_decoder_sequence_len,padding="post")
decoder_inp.shape
# Out:
# (175621, 61)

# %%
[arr[:-1] for arr in decoder][1]
# Out:
# [2, 551, 40]

# %%
decoder[3]
# Out:
# [2, 46, 6, 1]

# %%
decoder_output=pad_sequences([arr[1:] for arr in decoder],maxlen=max_decoder_sequence_len,padding="post")
decoder_output.shape
# Out:
# (175621, 61)

# %%
decoder_output
# Out:
# array([[15399,     1,     0, ...,     0,     0,     0],
#        [  551,    40,     1, ...,     0,     0,     0],
#        [ 4807,    40,     1, ...,     0,     0,     0],
#        ...,
#        [   14,   327,     7, ...,     0,     0,     0],
#        [ 7523,    10,    42, ...,     0,     0,     0],
#        [   59,   173,    22, ...,  2136,     1,     0]], dtype=int32)

# %%
[arr[1:] for arr in decoder][3]
# Out:
# [46, 6, 1]

# %%
# Design LSTM NN (Encoder & Decoder)

# %%
# encoder model
encoder_input=Input(shape=(None,),name="encoder_input_layer")
encoder_embedding=Embedding(num_encoder_tokens,50,input_length=max_encoder_sequence_len,name="encoder_embedding_layer")(encoder_input)
encoder_lstm=LSTM(32,activation="tanh",return_sequences=True,return_state=True,name="encoder_lstm_1_layer")(encoder_embedding)
encoder_lstm2=LSTM(32,activation="tanh",return_state=True,name="encoder_lstm_2_layer")(encoder_lstm)
_,state_h,state_c=encoder_lstm2
encoder_states=[state_h,state_c]

# %%
Embedding(num_encoder_tokens,300,input_length=max_encoder_sequence_len,name="encoder_embedding_layer")

# %%
Embedding(num_encoder_tokens,300,input_length=max_encoder_sequence_len,name="encoder_embedding_layer")(encoder_input)
# Out:
# <KerasTensor: shape=(None, None, 300) dtype=float32 (created by layer 'encoder_embedding_layer')>

# %%
# decoder model
decoder_input=Input(shape=(None,),name="decoder_input_layer")
decoder_embedding=Embedding(num_decoder_tokens,300,input_length=max_decoder_sequence_len,name="decoder_embedding_layer")(decoder_input)
decoder_lstm=LSTM(32,activation="tanh",return_state=True,return_sequences=True,name="decoder_lstm_layer")
decoder_outputs,_,_=decoder_lstm(decoder_embedding,initial_state=encoder_states)
decoder_dense=Dense(num_decoder_tokens+1,activation="softmax",name="deocer_final_layer")
outputs=decoder_dense(decoder_outputs)

# %%
model=Model([encoder_input,decoder_input],outputs)
model.summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  encoder_input_layer (InputLaye  [(None, None)]      0           []
#  r)
#
#  encoder_embedding_layer (Embed  (None, None, 50)    695250      ['encoder_input_layer[0][0]']
#  ding)
#
#  decoder_input_layer (InputLaye  [(None, None)]      0           []
#  r)
#
#  encoder_lstm_1_layer (LSTM)    [(None, None, 32),   10624       ['encoder_embedding_layer[0][0]']
#                                  (None, 32),
#                                  (None, 32)]
#
#  decoder_embedding_layer (Embed  (None, None, 300)   7238700     ['decoder_input_layer[0][0]']
#  ding)
#
#  encoder_lstm_2_layer (LSTM)    [(None, 32),         8320        ['encoder_lstm_1_layer[0][0]',
#                                  (None, 32),                      'encoder_lstm_1_layer[0][1]',
#                                  (None, 32)]                      'encoder_lstm_1_layer[0][2]']
#
#  decoder_lstm_layer (LSTM)      [(None, None, 32),   42624       ['decoder_embedding_layer[0][0]',
#                                  (None, 32),                      'encoder_lstm_2_layer[0][1]',
#                                  (None, 32)]                      'encoder_lstm_2_layer[0][2]']
#
#  deocer_final_layer (Dense)     (None, None, 24130)  796290      ['decoder_lstm_layer[0][0]']
#
# ==================================================================================================
# Total params: 8,791,808
# Trainable params: 8,791,808
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %%
encoder_seq.shape,decoder_inp.shape,decoder_output.shape
# Out:
# ((175621, 47), (175621, 61), (175621, 61))

# %%
loss = tf.losses.SparseCategoricalCrossentropy()
model.compile(optimizer='rmsprop', loss=loss, metrics=['accuracy'])
history=model.fit(
    [encoder_seq,decoder_inp],
    decoder_output,
    epochs=2,
    batch_size=64
)
# Out:
# Epoch 1/2
# 2745/2745 [==============================] - 232s 82ms/step - loss: 0.7957 - accuracy: 0.8833
# Epoch 2/2
# 2745/2745 [==============================] - 207s 76ms/step - loss: 0.7154 - accuracy: 0.8907
